# %%
# %%

import os
HOME = os.getcwd()
print(HOME)
# Out:
# /Users/aswin/Downloads/imouse/videos/cam_h06f

# %%
# %%

VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:2], video_paths[2:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
# 0it [00:00, ?it/s]

# %%
# %%

import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 0

# %%
# %%

VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:2], video_paths[2:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # %% [markdown]
#
#  **NOTE:** Notice that we put two of our videos aside so that we can use them at the end of the notebook to evaluate our model.

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:2], video_paths[2:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# 0it [00:00, ?it/s]

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:150], video_paths[150:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# 0it [00:00, ?it/s]

# %%
# %%

VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:150], video_paths[150:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# 0it [00:00, ?it/s]

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:150], video_paths[150:]
print('video count:', len(video_paths))
for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# video count: 0
# 0it [00:00, ?it/s]

# %%
# %%

VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10
print('video directory:', VIDEO_DIR_PATH)
# Out:
# video directory: /Users/aswin/Downloads/imouse/videos/cam_h06f/videos

# %%
# %%

VIDEO_DIR_PATH = f"{HOME}/videos"
IMAGE_DIR_PATH = f"{HOME}/images"
FRAME_STRIDE = 10
print('video directory:', VIDEO_DIR_PATH)
# Out:
# video directory: /Users/aswin/Downloads/imouse/videos/cam_h06f/videos

# %%
# %%

import supervision as sv
from tqdm.notebook import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])

TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:150], video_paths[150:]
print('video count:', len(video_paths))
for video_path in tqdm(TRAIN_VIDEO_PATHS):
    video_name = video_path.stem
    print(f"Processing video: {video_name}")
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Image name pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            print(f"Saving image: {image_name_pattern.format(sink.image_count)}")
            sink.save_image(image=image)
# Out:
# video count: 288
#   0%|          | 0/138 [00:00<?, ?it/s]
# Processing video: 53.23
# Image name pattern: 53.23-{:05d}.png
# Saving image: 53.23-00000.png
# Saving image: 53.23-00001.png
# Saving image: 53.23-00002.png
# Saving image: 53.23-00003.png
# Saving image: 53.23-00004.png
# Saving image: 53.23-00005.png
# Saving image: 53.23-00006.png
# Saving image: 53.23-00007.png
# Saving image: 53.23-00008.png
# Saving image: 53.23-00009.png
# Saving image: 53.23-00010.png
# Saving image: 53.23-00011.png
# Saving image: 53.23-00012.png
# Saving image: 53.23-00013.png
# Saving image: 53.23-00014.png
# Saving image: 53.23-00015.png
# Saving image: 53.23-00016.png
# Saving image: 53.23-00017.png
# Saving image: 53.23-00018.png
# Saving image: 53.23-00019.png
# Saving image: 53.23-00020.png
# Saving image: 53.23-00021.png
# Saving image: 53.23-00022.png
# Saving image: 53.23-00023.png
# Saving image: 53.23-00024.png
# Processing video: 44.13
# Image name pattern: 44.13-{:05d}.png
# ...

# %%
# %%

import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 3450

# %%
# %%

IMAGE_DIR_PATH = f"{HOME}/images"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 16)

# %%
# %%

import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %%
# %%

from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "mouse": "mouse",
    "food": "food"
})

# %%
# %%

DATASET_DIR_PATH = f"{HOME}/dataset"

# %%
# %%

from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# WARNING: CUDA not available. GroundingDINO will run very slowly.
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3588.)
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Labeling /Users/aswin/Downloads/imouse/videos/cam_h06f/images/21.06-00002.png:   0%|          | 0/3450 [00:00<?, ?it/s]The `device` argument is deprecated and will be removed in v5 of Transformers.
# ...
